# %%
import numpy as np
from desc.plotting import plot_comparison
import desc.io
from desc.vmec import VMECIO

# %%
QA = desc.io.load("eq_QA_nfp2_AP6_iotaedge_0d42.h5")
QH = desc.io.load("eq_QH_nfp4_AR6_iotaedge_1d30.h5")
QI = desc.io.load("eq_QI_nfp2_AP6_iotaedge_0d61.h5")

# %%
plot_comparison([QA, QH, QI], phi=np.linspace(0, np.pi, 6, endpoint=False));

# %%
VMECIO.write_vmec_input(QA, "input.eq_QA_nfp2_AR6_new")
VMECIO.write_vmec_input(QH, "input.eq_QH_nfp4_AR6_new")
VMECIO.write_vmec_input(QI, "input.eq_QI_nfp2_AR6_new")
