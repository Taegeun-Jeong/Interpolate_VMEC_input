# %%
from desc.vmec import VMECIO
import desc.io
from desc.plotting import plot_3d, plot_comparison, plot_1d, plot_boozer_surface

# %%
QA = desc.io.load("../input/eq_QA_nfp2_AP6_iotaedge_0d42.h5")
QH = desc.io.load("../input/QH_precise_QA_8.h5")
QI = desc.io.load("../input/eq_QI_nfp2_AP6_iotaedge_0d61.h5")

# %%
plot_1d(QA, 'iota');
plot_1d(QH, 'iota');
plot_1d(QI, 'iota');

# %%
VMECIO.write_vmec_input(QA, '../input/input.eq_QA_nfp2_AR6_iotaedge_0d42')
VMECIO.write_vmec_input(QH, '../input/input.eq_QH_nfp2_AR6_iotaedge_0d56')
VMECIO.write_vmec_input(QI, '../input/input.eq_QI_nfp2_AR6_iotaedge_0d61')
